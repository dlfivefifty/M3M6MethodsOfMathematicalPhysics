# %%
using Plots, Colors
gr();

# %%
img = Gray.(rand(100,100))
# Out:
# 100×100 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.507366)   …  Gray{Float64}(0.474202)
#  Gray{Float64}(0.052929)      Gray{Float64}(0.830385)
#  Gray{Float64}(0.750873)      Gray{Float64}(0.417303)
#  Gray{Float64}(0.541977)      Gray{Float64}(0.997933)
#  Gray{Float64}(0.226973)      Gray{Float64}(0.414358)
#  Gray{Float64}(0.896281)   …  Gray{Float64}(0.610306)
#  Gray{Float64}(0.112239)      Gray{Float64}(0.574129)
#  Gray{Float64}(0.784207)      Gray{Float64}(0.687741)
#  Gray{Float64}(0.642241)      Gray{Float64}(0.0351678)
#  Gray{Float64}(0.620674)      Gray{Float64}(0.716903)
#  Gray{Float64}(0.169101)   …  Gray{Float64}(0.0329251)
#  Gray{Float64}(0.628069)      Gray{Float64}(0.795619)
#  Gray{Float64}(0.613415)      Gray{Float64}(0.532955)
#  ⋮                         ⋱
#  Gray{Float64}(0.0213392)     Gray{Float64}(0.411288)
#  Gray{Float64}(0.546324)      Gray{Float64}(0.170882)
#  Gray{Float64}(0.41785)    …  Gray{Float64}(0.691538)
# ...

# %%
plot(img; xscale=(0,10), ylims=(0,20))
# Out:
# ┌ Warning: scale (0, 10) is unsupported with Plots.GRBackend().  Choose from: Symbol[:identity, :log10]
# └ @ Plots /Users/sheehanolver/.julia/packages/Plots/UtVfv/src/args.jl:1169
# MethodError: no method matching scalefunc(::Tuple{Int64,Int64})
# Closest candidates are:
#   scalefunc(!Matched::Symbol) at /Users/sheehanolver/.julia/packages/Plots/UtVfv/src/axes.jl:151
#
# Stacktrace:
#  [1] optimal_ticks_and_labels(::Plots.Axis, ::Nothing) at /Users/sheehanolver/.julia/packages/Plots/UtVfv/src/axes.jl:160
#  [2] optimal_ticks_and_labels at /Users/sheehanolver/.julia/packages/Plots/UtVfv/src/axes.jl:156 [inlined]
#  [3] get_ticks(::Plots.Axis) at /Users/sheehanolver/.julia/packages/Plots/UtVfv/src/axes.jl:264
#  [4] axis_drawing_info(::Plots.Subplot{Plots.GRBackend}) at /Users/sheehanolver/.julia/packages/Plots/UtVfv/src/axes.jl:591
#  [5] _update_min_padding!(::Plots.Subplot{Plots.GRBackend}) at /Users/sheehanolver/.julia/packages/Plots/UtVfv/src/backends/gr.jl:643
# ...
