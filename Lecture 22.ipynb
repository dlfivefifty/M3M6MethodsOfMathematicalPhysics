# %%
using Plots, ComplexPhasePortrait, ApproxFun, SingularIntegralEquations, OscillatoryIntegrals, 
        SpecialFunctions
gr();
# Out:
# INFO: Recompiling stale cache file /Users/solver/.julia/lib/v0.6/OscillatoryIntegrals.ji for module OscillatoryIntegrals.

# %% [markdown]
# # M3M6: Methods of Mathematical Physics
#
# $$
# \def\dashint{{\int\!\!\!\!\!\!-\,}}
# \def\infdashint{\dashint_{\!\!\!-\infty}^{\,\infty}}
# \def\D{\,{\rm d}}
# \def\E{{\rm e}}
# \def\dx{\D x}
# \def\dt{\D t}
# \def\dz{\D z}
# \def\C{{\mathbb C}}
# \def\R{{\mathbb R}}
# \def\H{{\mathbb H}}
# \def\CC{{\cal C}}
# \def\HH{{\cal H}}
# \def\FF{{\cal F}}
# \def\I{{\rm i}}
# \def\qqqquad{\qquad\qquad}
# \def\qqand{\qquad\hbox{and}\qquad}
# \def\qqfor{\qquad\hbox{for}\qquad}
# \def\qqwhere{\qquad\hbox{where}\qquad}
# \def\Res_#1{\underset{#1}{\rm Res}}\,
# \def\sech{{\rm sech}\,}
# \def\acos{\,{\rm acos}\,}
# \def\erfc{\,{\rm erfc}\,}
# \def\vc#1{{\mathbf #1}}
# \def\ip<#1,#2>{\left\langle#1,#2\right\rangle}
# \def\norm#1{\left\|#1\right\|}
# \def\half{{1 \over 2}}
# \def\fL{f_{\rm L}}
# \def\fR{f_{\rm R}}
# $$
#
# Dr Sheehan Olver
# <br>
# s.olver@imperial.ac.uk
#
# Office Hours: 3-4pm Mondays, 11-12am Thursdays, Huxley 6M40
# <br>
# Website: https://github.com/dlfivefifty/M3M6LectureNotes
#
#
#
# # Lecture 22:  Cauchy transforms on the real line
#
# Our goal is to solve the integral equation
# $$
# \lambda u(x) + \int_{0}^\infty K(x-t)u(t) \dt = f(x)\qqfor 0 < x < \infty.
# $$
# We will demonstrate the procedure for the special case $K(x) = \E^{-\gamma |x|}$.
#
# Taking Fourier transforms, we get functions analytic above or below the real axis, giving us a Riemann–Hilbert problem of finding $\Phi(z)$ analytic off $(-\infty,\infty)$ such that
# $$
# \Phi_+(s) - g(s)\Phi_-(s) = h(s) \qqand \Phi(\infty) = C
# $$
# where $\Phi_\pm(s) = \lim_{\epsilon \rightarrow 0} \Phi(s \pm \I \epsilon)$ are the limits from above and below.  Here $g$ and $h$ are given, and $g(\pm \infty) = 1$.
#
# Outline:
#
# 1. Integral equation to Riemann–Hilbert problem
# 2. Cauchy transforms on the Real line
#    - Application: Calculating error functions
#
# ## Integral equation to Riemann–Hilbert problem
#
# Recall the notation
# $$
# f_{\rm R}(x) = \begin{cases}f(t) & t \geq 0 \\ 0 & \hbox{otherwise} \end{cases}
# $$
# and
# $$
# f_{\rm L}(x) = \begin{cases}f(t) & t < 0 \\ 0 & \hbox{otherwise} \end{cases}
# $$
#
# Using this, we can rewrite the integral equation on the half line
# $$
# \lambda u(x) + \int_{0}^\infty K(x-t)u(t) \dt = f(x)\qqfor 0 < x < \infty.
# $$
# as an integral equation on the whole line:
# $$
# \lambda u_{\rm R}(x) + \int_{-\infty}^\infty K(x-t)u_{\rm R}(t) \dt = f_{\rm R}(x) + p_{\rm L}(x)\qqfor -\infty < x < \infty.
# $$
# where
# $$
# p(x) = \int_{-\infty}^\infty K(x-t)u_{\rm R}(t) \dt
# $$
# Taking Fourier transforms, this becomes:
# $$
# (\lambda + \widehat K(s)) \widehat{u_{\rm R}}(s) = \widehat{f_{\rm R}}(s) + \widehat{p_{\rm L}}(s)
# $$
# As discussed last lecture, assuming $u$ is "nice" we are guaranteed that $\widehat{ u_{\rm R}}(s)$ is analytic in the lower half-plane and $\widehat{ p_{\rm L}}(s)$ is analytic in the upper-half plane.  Thus introduce the sectionally analytic function:
# $$
# \Phi(z) = \begin{cases}  \widehat{p_{\rm L}}(z) & \Im z > 0 \\
#                             \widehat{u_{\rm R}}(z) & \Im z < 0
#                             \end{cases}
# $$
# Then our integral transformed integral equation becomes:
# $$
# \underbrace{\Phi_+(s)}_{\widehat{p_{\rm L}}(s)} - \underbrace{g(s)}_{\lambda + \widehat K(s)} \underbrace{\Phi_-(s)}_{\widehat{u_{\rm R}}(s)} = \underbrace{h(s)}_{\widehat{f_{\rm R}}(s) } \qqand \Phi(\infty) = 0
# $$
#
# Here there is one unknown $\Phi(z)$, and we claim that in certain conditions this has one—and only—one solution. Thus we wish to:
#
# 1. Find $\Phi(z)$
# 2. Recover $u(x)$ via the inverse Fourier transform ${\cal F}^{-1} \Phi_-$
#
# ## Cauchy transforms on the real line
#
# Not surprisingly, the key tool to solving the Riemann–Hilberrt problem is going to be the Cauchy transform over the real line:
# $$
# \CC_\R f(z) = {1 \over 2 \pi \I}\int_{-\infty}^\infty {f(s)  \over s-z} \D s
# $$
#
# This is no longer analytic at $\infty$ because the contour of integration passes through there, but we still have Plemelj's theorem under reasonable assumptions:
#
# **Theorem (Plemelj on the real line)**  Assume that $f : \R \rightarrow \C$ is continuously-differentiable and both it and its derivatives are absolutely integrable. Then $\CC f(z)$ is the unique function satisfying the following properties:
# 1. $\CC f(z)$ is analytic off $\R$
# 2. $\lim_{z\rightarrow \infty} \CC f(z) = 0$ in any direction
# 3. $\CC^+ f(x) - \CC^- f(x)  = f(x)$ for $x \in \R$
#
#
#
# ### Application: Calculating error functions
#
# Consider the complementary Error function
# $$
# \erfc z = {2 \over \sqrt \pi} \int_z^\infty \E^{-\zeta^2} \D \zeta.
# $$
# We will show that this special function can be reduced to a Cauchy transform over the real line.
# This function is particularly important in statistics: on the real axis $1-\erfc x$  gives the cummulative density function (CDF) of the Gaussian distribution:
#
# $$\int_{-\infty}^x {\E^{-x^2} \over \sqrt \pi} \dx = 1-{\erfc x\over 2}$$

# %%
x = Fun(-10 .. 10)
plot(cumsum(exp(-x^2)/sqrt(π)))
plot!(1-erfc(x)/2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4600)" points="
# 38.8117,375.813 580.315,375.813 580.315,11.811 38.8117,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="38" y="11" width="543" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   106.498,370.353 106.498,17.2711
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   174.187,370.353 174.187,17.2711
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.875,370.353 241.875,17.2711
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.563,370.353 309.563,17.2711
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   377.252,370.353 377.252,17.2711
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   444.94,370.353 444.94,17.2711
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   512.628,370.353 512.628,17.2711
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,375.813 572.192,375.813
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,284.813 572.192,284.813
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,193.812 572.192,193.812
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,102.812 572.192,102.812
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.9343,11.811 572.192,11.811
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 38.8117,11.811
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   106.498,375.813 106.498,370.353
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   174.187,375.813 174.187,370.353
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.875,375.813 241.875,370.353
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.563,375.813 309.563,370.353
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   377.252,375.813 377.252,370.353
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   444.94,375.813 444.94,370.353
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   512.628,375.813 512.628,370.353
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 46.9343,375.813
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,284.813 46.9343,284.813
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,193.812 46.9343,193.812
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,102.812 46.9343,102.812
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,11.811 46.9343,11.811
#   "/>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 106.498, 389.613)" x="106.498" y="389.613">-7.5</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 174.187, 389.613)" x="174.187" y="389.613">-5.0</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 241.875, 389.613)" x="241.875" y="389.613">-2.5</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.563, 389.613)" x="309.563" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 377.252, 389.613)" x="377.252" y="389.613">2.5</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 444.94, 389.613)" x="444.94" y="389.613">5.0</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 512.628, 389.613)" x="512.628" y="389.613">7.5</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 380.313)" x="32.8117" y="380.313">0.00</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 289.313)" x="32.8117" y="289.313">0.25</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 198.312)" x="32.8117" y="198.312">0.50</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 107.312)" x="32.8117" y="107.312">0.75</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 16.311)" x="32.8117" y="16.311">1.00</text>
# </g>
# <polyline clip-path="url(#clip4602)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,11.811 580.302,11.811
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.302,

# %% [markdown]
# Note that $\erfc z$ is entire (it's complex-derivative is of course ${2 \over \sqrt \pi} \E^{-z^2}$) but is not nice at $\infty$:

# %%
phaseplot(z -> erfc(z), (-3,3), (-3,3))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran

# %% [markdown]
# But integrating by parts we see that the dominant behaviour is like $\E^{-z^2}$,
# $$
# \int_z^\infty \E^{-\zeta^2} \D \zeta = \int_z^\infty  -2\zeta {\E^{-\zeta^2} \over -2 \zeta}  \D \zeta = {\E^{-z^2} \over 2 z} -\int_z^\infty {\E^{-\zeta^2} \over 2 \zeta^2} \D \zeta
# $$
# and indeed $\E^{z^2} \erfc z$ decays in the right-half plane:

# %%
phaseplot(z -> exp(z^2)erfc(z), (-3,3), (-3,3))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran

# %% [markdown]
# Note that
# $$
# {2 \over \sqrt\pi} \int_{-\infty}^z \E^{-\zeta^2} \D \zeta = {2 \over \sqrt\pi} \left[\int_{-\infty}^\infty - \int_z^\infty\right] \E^{-\zeta^2} \D \zeta = 2 - \erfc(z)
# $$
# and has similar properties in the left-hand plane:

# %%
phaseplot(z -> exp(z^2)*(2-erfc(z)), (-3,3), (-3,3))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran

# %% [markdown]
# Now consider the function
# $$
# \phi(z) = \begin{cases}     \E^{z^2}(2-\erfc( z) )& \Re z < 0 \\
#                             -\E^{z^2} \erfc(z) & \Re z > 0
#                             \end{cases}
# $$
# This decays everywhere, and has the jumps for $s$ on the imaginary axis:
# $$
# \phi_+(s) - \phi_-(s) = 2\E^{s^2}
# $$
# where we have oriented from $-\I\infty$ to $\I \infty$, hence $\phi_+(s) = \lim_{\epsilon\rightarrow 0} \phi(s-\epsilon)$ and $\phi_-(s) = \lim_{\epsilon\rightarrow 0} \phi(s+\epsilon)$.

# %%
φ = z -> real(z) < 0 ? 
            exp(z^2)*(2-erfc(z)) : 
           -exp(z^2)*erfc(z)

phaseplot(φ , (-3,3), (-3,3))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran

# %%
s = im
φ(s-eps())-φ(s+eps())
# Out:
# 0.7357588823428849 + 0.0im

# %%
2exp(s^2)
# Out:
# 0.7357588823428847 + 0.0im

# %% [markdown]
# Thus by Plemelj, we have
# $$
# \phi(z) = 2\CC_{(-\I\infty,\I\infty)}[\E^{\diamond^2}](z)
# $$
# or by rotating to the real axis,
# $$
# \phi(z) = 2\CC_{(-\infty,\infty)}[\E^{-\diamond^2}](-\I z).
# $$
# In other words,
# $$
# \erfc  z = -2 \E^{-z^2}\CC_{(-\infty,\infty)}[\E^{-\diamond^2}](-\I z) + \begin{cases}
# 2 & \Re z < 0 \\
# 0 & \Re z > 0
# \end{cases}
# $$

# %%
let f = Fun(x -> exp(-x^2), PeriodicLine())
    global myerf(z) =  -2exp(-z^2)*cauchy(f, -im*z) + (real(z) < 0 ? 2 : 0)
end
# Out:
# myerf (generic function with 1 method)

# %%
z = -2.0+2.0im
@time myerf(z)
# Out:
#   0.000116 seconds (1000 allocations: 61.625 KiB)
# 2.151310866398069 - 0.12729162946314043im

# %%
@time erfc(z)
# Out:
#   0.000005 seconds (5 allocations: 192 bytes)
# 2.151310866398069 - 0.12729162946314082im

# %% [markdown]
# ## Homogenous Riemann–Hilbert problems on the real line
#
# Back to the Riemann–Hilbert problem, but let's assume $f$ is zero. Consider
# $$
# \Phi_+(s) = g(s) \Phi_-(s) \qqand \Phi(\infty) = I
# $$
#
# Note that if $C \Phi(z)$ satisfies the same jump with $\Phi(\infty) = C$. Formally, taking logs of both sides reduces this to a subtractive RH problem:
# $$
# \log \Phi_+(s) - \log\Phi_-(s) = \log g(s) ?
# $$
# Assuming that $g(s) \rightarrow 1$ as $s \rightarrow \pm \infty$ at a sufficient rate, this motivates the guess
# $$
# \Phi(z) = \E^{\CC[\log g](z)}
# $$
