# %%
using Plots, ComplexPhasePortrait, Interact, ApproxFun
gr();

# %% [markdown]
# # M3M6: Methods of Mathematical Physics
#
# Dr. Sheehan Olver
# <br>
# s.olver@imperial.ac.uk
#
# Office Hours: 3-4pm Mondays, Huxley 6M40
# <br>
# Website: Blackboard
#
#
#
# # Lecture 4: Trapezium rule, Fourier series and Laurent series
#
#
# This lecture we cover
#
# 1. Periodic and complex Trapezium rule
#     - Application: Calculating matrix exponentials
# 1. Laurent series and Fourier series
#     - Application: Decay of Fourier coefficients

# %% [markdown]
# ### Periodic and complex Trapezium rule
#
# Quadrature rules are pairs of _nodes_ $x_0,\ldots,x_{n-1}$ and weights $w_0,\ldots,w_{n-1}$ to approximate integrals
# $$
# \int_a^b f(x) dx \approx \sum_{j=0}^{n-1} w_j f(x_j)
# $$
# In this lecture we construct quadrature rules on complex contours $\gamma$ to approximate contour integrals.
#
#
# The Trapezium rule gives an easy approximation to integrals. On $[0,2\pi)$ for periodic $f(\theta)$, we have a simplified form:
#
# **Definition (Periodic trapezium rule)** The _periodic trapezium rule_ is the approximation
#
# $$\int_0^{2 \pi} f(\theta) d \theta \approx {2\pi \over n} \sum_{j=0}^{n-1} f(\theta_k)$$
#
# for $\theta_j = {2 \pi j \over n}$.
#
# The periodic trapezium rule is amazingly accurate for smooth, periodic functions:

# %%
periodic_rule(n) = 2π/n*(0:(n-1)), 2π/n*ones(n)

f = θ -> 1/(2 + cos(θ))

x, w = periodic_rule(30)
sum(w.*f.(x)) - sum(Fun(f, 0 .. 2π))
# Out:
# 4.440892098500626e-16

# %%
plot(Fun(f, 0 .. 2π); label = "integrand")
plot!(x, f.(x); label = "trapezium approximation")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,370.353 32.2221,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   119.454,370.353 119.454,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   206.686,370.353 206.686,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   293.919,370.353 293.919,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   381.151,370.353 381.151,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   468.383,370.353 468.383,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   555.615,370.353 555.615,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,339.413 572.094,339.413
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,284.813 572.094,284.813
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,230.212 572.094,230.212
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,175.612 572.094,175.612
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,121.012 572.094,121.012
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,66.4114 572.094,66.4114
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,11.811 572.094,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   119.454,375.813 119.454,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   206.686,375.813 206.686,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   293.919,375.813 293.919,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   381.151,375.813 381.151,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   468.383,375.813 468.383,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   555.615,375.813 555.615,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,339.413 40.4435,339.413
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,284.813 40.4435,284.813
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,230.212 40.4435,230.212
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,175.612 40.4435,175.612
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,121.012 40.4435,121.012
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,66.4114 40.4435,66.4114
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,11.811 40.4435,11.811
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 389.613)" x="32.2221" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 119.454, 389.613)" x="119.454" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 206.686, 389.613)" x="206.686" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 293.919, 389.613)" x="293.919" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 381.151, 389.613)" x="381.151" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 468.383, 389.613)" x="468.383" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 555.615, 389.613)" x="555.615" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 343.913)" x="26.2221" y="343.913">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 289.313)" x="26.2221" y="289.313">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 234.712)" x="26.2221" y="234.712">0.6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 180.112)" x="26.2221" y="180.112">0.7</t

# %% [markdown]
# This immediately gives an approximation on a closed contour $\gamma$:
#
# **Definition (Complex trapezium rule)** The _complex trapezium rule_ on a contour $\gamma$ (mapped from $[0,2\pi)$) is the approximation
#
# $$\oint_\gamma f(z) dz \approx  \sum_{j=0}^{n-1} w_j f(z_j)$$
#
# for
#
# $$z_j = \gamma(\theta_j) \qquad\hbox{and}\qquad w_j = {2\pi \over n} \gamma'(\theta_j)$$
#
#
# *Example (Circle trapezium rule)* On a circle $\{r e^{i \theta} : 0 \leq \theta < 2 \pi\}$, we have
# $$\oint_\gamma f(z) dz \approx  \sum_{j=0}^{n-1} w_j f(z_j)$$
# for $z_j = r e^{i \theta_j}$ and $w_j = {2 \pi i r \over n}  e^{i \theta_j}$.
#
# The Circle trapezium rule is surprisingly accurate for analytic functions:

# %%
function circle_rule(n, r) 
    θ = periodic_rule(n)[1]
    r*exp.(im*θ), 2π*im*r/n*exp.(im*θ)
end

z, w = circle_rule(20, 1.0)
sum(exp.(z)./(z-0.1).*w)/(2π*im) - exp(0.1)
# Out:
# -2.220446049250313e-16 + 1.766974823035287e-17im

# %%
θ = periodic_rule(100)[1]
plot(θ, real(exp.(exp.(im*θ))./(exp.(im*θ) - 0.1)))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 22.3377,375.813 580.315,375.813 580.315,11.811 22.3377,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="22" y="11" width="559" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.3377,370.353 22.3377,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   112.04,370.353 112.04,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   201.741,370.353 201.741,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   291.443,370.353 291.443,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   381.145,370.353 381.145,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   470.847,370.353 470.847,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   560.549,370.353 560.549,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,339.526 571.945,339.526
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,231.022 571.945,231.022
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,122.519 571.945,122.519
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,14.0151 571.945,14.0151
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 22.3377,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   112.04,375.813 112.04,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   201.741,375.813 201.741,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   291.443,375.813 291.443,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   381.145,375.813 381.145,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   470.847,375.813 470.847,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   560.549,375.813 560.549,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 22.3377,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,339.526 30.7073,339.526
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,231.022 30.7073,231.022
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,122.519 30.7073,122.519
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,14.0151 30.7073,14.0151
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 22.3377, 389.613)" x="22.3377" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 112.04, 389.613)" x="112.04" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 201.741, 389.613)" x="201.741" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 291.443, 389.613)" x="291.443" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 381.145, 389.613)" x="381.145" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 470.847, 389.613)" x="470.847" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 560.549, 389.613)" x="560.549" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 344.026)" x="16.3377" y="344.026">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 235.522)" x="16.3377" y="235.522">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 127.019)" x="16.3377" y="127.019">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 18.5151)" x="16.3377" y="18.5151">3</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,11.811 27.9738,12.5448 33.6099,14.734 39.2461,18.3434 44.8822,23.3153 50.5183,29.5723 56.1545,37.0193 61.7906,45.5475 67.4267,55.0372 73.0629,65.3621
#   78.699,76.3922 84.3351,87.9978 89.9713,100.052 95.6074,112.434 101.244,125.029 106.88,137.732 112.516,150.45 118.152,163.098 123.788,175.601 129.424,187.898
#   135.06,199.934 140.696,211.666 146.333,223.057 151.969,234.078 157.605,244.709 163.241,254.932 168.877,264.735 174.513,274.111 180.149,283.056 185.786,291.566
#   191.422,299.642 197.058,307.287 202.694,314.501 208.33,321.29 213.966,327.658 219.602,333.608 225.238,339.147 230.875,344.278 236.511,349.007 242.147,353.339
#   247.783,357.277 253.419,360.827 259.055,363.992 264.691,366.777 270.328,369.183 275.964,371.214 281.6,372.872 287.236,374.16 292.872,375.079 298.508,375.63
#   304.144,375.8

# %%
f = z -> exp(z)

err = [((z, w) = circle_rule(n, 1.0);
    abs(sum(f.(z)./(z-0.1).*w)/(2π*im) - f(0.1))) for n = 1:20]

plot(err; yscale=:log10)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 54.5866,375.813 580.315,375.813 580.315,11.811 54.5866,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="11" width="527" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   165.266,370.353 165.266,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   303.616,370.353 303.616,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   441.965,370.353 441.965,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,360.915 572.429,360.915
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,246.696 572.429,246.696
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,132.477 572.429,132.477
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,18.2576 572.429,18.2576
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   165.266,375.813 165.266,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   303.616,375.813 303.616,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   441.965,375.813 441.965,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,375.813 54.5866,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,360.915 62.4725,360.915
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,246.696 62.4725,246.696
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,132.477 62.4725,132.477
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,18.2576 62.4725,18.2576
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 165.266, 389.613)" x="165.266" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 303.616, 389.613)" x="303.616" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 441.965, 389.613)" x="441.965" y="389.613">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 365.415)" x="48.5866" y="365.415">10^-15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 251.196)" x="48.5866" y="251.196">10^-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 136.977)" x="48.5866" y="136.977">10^-5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 22.7576)" x="48.5866" y="22.7576">10^0</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,11.811 82.2565,23.796 109.926,35.6385 137.596,49.5555 165.266,65.5744 192.936,83.3797 220.606,102.705 248.276,123.35 275.946,145.16 303.616,168.013
#   331.286,191.81 358.956,216.468 386.626,241.919 414.295,268.103 441.965,294.973 469.635,322.517 497.305,351.189 524.975,375.721 552.645,375.775 580.315,375.813
#
#   "/>
# <polygon clip-path="url(#clip00)" points="
# 489.799,62.931 562.315,62.931 562.315,32.691 489.799,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   489.799,62.931 562.315,62.931 562.315,32.691 489.799,32.691 489.799,62.931
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   495.799,47.811 531.799,47.811
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 537.799, 52.311)" x="537.799" y="52.311">y1</text>
# </g>
# </svg>

# %% [markdown]
# *Example (Ellipse trapezium rule)* On an ellipse $\{a \cos \theta + b i \sin \theta : 0 \leq \theta < 2 \pi\}$ we have
# $$\oint_\gamma f(z) dz \approx  \sum_{j=0}^{n-1} w_j f(z_j)$$
# for $z_j = a \cos \theta_j + b i \sin \theta_j$ and $w_j = {2 \pi \over n} (-a \sin \theta_j + i b \cos \theta_j)$.

# %%
function ellipse_rule(n, a, b) 
    θ = periodic_rule(n)[1]
    a*cos.(θ) + b*im*sin.(θ), 2π/n*(-a*sin.(θ) + im*b*cos.(θ))
end



z, w = ellipse_rule(100, 1, 0.5)
sum(f.(z)./(z-0.1).*w)/(2π*im) - f(0.1)
# Out:
# -2.220446049250313e-16 - 4.086129278269101e-17im

# %%
plot(z)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 54.8916,360.065 580.315,360.065 580.315,11.811 54.8916,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="11" width="526" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.8916,354.842 54.8916,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   186.247,354.842 186.247,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   317.603,354.842 317.603,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   448.959,354.842 448.959,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,354.842 580.315,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,325.515 572.434,325.515
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,255.727 572.434,255.727
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,185.938 572.434,185.938
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,116.15 572.434,116.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,46.361 572.434,46.361
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 54.8916,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   186.247,360.065 186.247,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   317.603,360.065 317.603,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   448.959,360.065 448.959,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 54.8916,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,325.515 62.773,325.515
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,255.727 62.773,255.727
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,185.938 62.773,185.938
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,116.15 62.773,116.15
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,46.361 62.773,46.361
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 54.8916, 373.865)" x="54.8916" y="373.865">-1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 186.247, 373.865)" x="186.247" y="373.865">-0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 317.603, 373.865)" x="317.603" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 448.959, 373.865)" x="448.959" y="373.865">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 330.015)" x="48.8916" y="330.015">-0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 260.227)" x="48.8916" y="260.227">-0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 190.438)" x="48.8916" y="190.438">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 120.65)" x="48.8916" y="120.65">0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 50.861)" x="48.8916" y="50.861">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 317.603, 397.6)" x="317.603" y="397.6">Re(x)</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">Im(x)</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,185.938 578.243,164.071 572.061,142.549 561.866,121.711 547.819,101.886 530.141,83.3865 509.112,66.5043 485.062,51.5056 458.371,38.6271 429.46,28.0717
#   398.786,20.006 366.831,14.5571 334.099,11.811 301.107,11.811 268.376,14.5571 236.421,20.006 205.746,28.0717 176.835,38.6271 150.145,51.5056 126.095,66.5043
#   105.065,83.3865 87.3873,101.886 73.3402,121.711 63.1452,142.549 56.9632,164.071 54.8916,185.938 56.9632,207.805 63.1452,229.328 73.3402,250.165 87.3873,269.99
#   105.065,288.49 126.095,305.372 150.145,320.371 176.835,333.249 205.746,343.805 236.421,351.87 268.376,357.319 301.107,360.065 334.099,360.065 366.831,357.319
#   398.786,351.87 429.46,343.805 458.371,333.249 485.062,320.371 509.112,305.372 530.141,288.49 547.819,269.99 561.866,250.165 572.061,229.328 578.243,207.805
#
#   "/>
# <polygon clip-path="url(#clip00)" points="
# 489.799,62.931 562.315,62.93

# %% [markdown]
# ### Application: calculating matrix exponentials
#
# Let $A \in {\mathbb C}^{n \times n}$,   ${\mathbf u}_0 \in {\mathbb C}^n$ and consider the constant coefficient linear ODE
#
# $$
#     {\mathbf u}'(t) = A {\mathbf u}(t)\qquad\hbox{and}\qquad {\mathbf u}(0) = {\mathbf u}_0(0)
#     $$
#
# The solution to this is given by the _matrix exponential_
# $$
#     {\mathbf u}(t) = \exp(A t) {\mathbf u}_0
#     $$
#     where the matrix exponential is defined by it's Taylor series:
# $$
#     \exp(A) = \sum_{k=0}^\infty {A^k \over k!}
#     $$
# This has stability problems, so a more convenient form is as follows:
#
# **Theorem (Cauchy integral representation for matrix exponential)**
# Let $A \in {\mathbb C}^{n \times n}$ be a diagonalizable matrix:
# $$
#     A = V \Lambda V^{-1} \qquad\hbox{for}\qquad\Lambda =
#     \begin{pmatrix}\lambda_1 \cr &\ddots \cr && \lambda_n\end{pmatrix}
# $$
# Let $\gamma$ be a contour that surrounds the spectrum of $A$. Then we have
# $$
#     \exp(A) = {1 \over 2 \pi i} \oint_\gamma f(z) (z I - A)^{-1} dz
#     $$

# %%
A = randn(5,5)
A = A + A'
λ = eigvals(A)
# Out:
# 5-element Array{Float64,1}:
#  -6.40088
#  -2.48538
#  -1.08057
#   1.04364
#   2.83926

# %%
z,w = circle_rule(100,7.0)

plot(z)
scatter!(λ,zeros(5); label = "eigenvalues of A")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 54.8916,360.065 580.315,360.065 580.315,11.811 54.8916,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="11" width="526" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   140.574,354.842 140.574,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   229.089,354.842 229.089,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   317.603,354.842 317.603,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   406.118,354.842 406.118,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   494.633,354.842 494.633,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,303.275 572.434,303.275
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,244.606 572.434,244.606
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,185.938 572.434,185.938
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,127.27 572.434,127.27
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.773,68.6018 572.434,68.6018
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   140.574,360.065 140.574,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   229.089,360.065 229.089,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   317.603,360.065 317.603,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   406.118,360.065 406.118,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   494.633,360.065 494.633,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 54.8916,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,303.275 62.773,303.275
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,244.606 62.773,244.606
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,185.938 62.773,185.938
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,127.27 62.773,127.27
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,68.6018 62.773,68.6018
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 140.574, 373.865)" x="140.574" y="373.865">-5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 229.089, 373.865)" x="229.089" y="373.865">-2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 317.603, 373.865)" x="317.603" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 406.118, 373.865)" x="406.118" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 494.633, 373.865)" x="494.633" y="373.865">5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 307.775)" x="48.8916" y="307.775">-5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 249.106)" x="48.8916" y="249.106">-2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 190.438)" x="48.8916" y="190.438">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 131.77)" x="48.8916" y="131.77">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 73.1018)" x="48.8916" y="73.1018">5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 317.603, 397.6)" x="317.603" y="397.6">Re(x)</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">Im(x)</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   565.444,185.938 564.955,175.624 563.49,165.35 561.055,155.157 557.658,145.086 553.314,135.176 548.04,125.466 541.857,115.995 534.788,106.8 526.863,97.9174
#   518.111,89.3822 508.568,81.228 498.272,73.487 487.262,66.1899 475.583,59.3653 463.281,53.0402 450.403,47.2397 437.002,41.9865 423.129,37.3014 408.84,33.203
#   394.19,29.7073 379.239,26.8282 364.044,24.577 348.666,22.9626 333.165,21.9914 317.603,21.6673 302.041,21.9914 286.541,22.9626 271.162,24.577 255.968,26.8282
#   241.016,29.7073 226.367,33.203 212.078,37.3014 198.205,41.9865 184.803,47.2397 171.926,53.0402 159.623,59.3653 147.944,66.1899 136.935,73.487 126.638,81.228
#   117.096,89.3822 108.344,97.9174 100.418,106.8 93.3499,115.995 87.1664,125.466 81.8923,135.176 77.5485,145.086 74.152,155.157 71.7164,165.35 70.2511,175.624
#   69.7621,185.938 70.2511,196.253 71.7164,206.527 74.152,216.72 77.5485,226.791 8

# %%
function circle_expm(A, n, z₀, r)
    z,w = circle_rule(n,r)
    z .+= z₀

    ret = zeros(A)
    for j=1:n
        ret += w[j]*exp(z[j])*inv(z[j]*I - A)
    end

    ret/(2π*im)
end
   
circle_expm(A, 100, 0, 8.0) -expm(A) |>norm
# Out:
# 4.204078563780952e-13

# %%
function ellipse_expm(A, n, z₀, a, b)
    z,w = ellipse_rule(n,a,b)
    z .+= z₀

    ret = zeros(A)
    for j=1:n
        ret += w[j]*exp(z[j])*inv(z[j]*I - A)
    end
    ret/(2π*im)
end


ellipse_expm(A, 50, 0, 8.0, 5.0) -expm(A) |>norm
# Out:
# 9.180736837923729e-14

# %%
function taylor_expm(A,n)
    ret = eye(A)
    for k=1:n
        ret += A^k/factorial(1.0k)
    end
    ret
end

B = A - 20I

taylor_expm(B, 200) -expm(B) |>norm
# Out:
# 8.116477110896933e-6

# %%
eigvals(B)
# Out:
# 5-element Array{Float64,1}:
#  -26.4009
#  -22.4854
#  -21.0806
#  -18.9564
#  -17.1607

# %%
norm(ellipse_expm(B, 50, -20.0, 8.0, 5.0) - expm(B))
# Out:
# 4.48015547278161e-22

# %% [markdown]
# ## Fourier series and Laurent series
#
# **Definition (Fourier series)** On $[-\pi, \pi)$,  _Fourier series_ is an expansion of the form
# $$
#     g(\theta) = \sum_{k=-\infty}^\infty g_k e^{i k \theta}
# $$
# where
# $$
# g_k = {1\over 2 \pi} \int_{-\pi}^\pi g(\theta) e^{-i k \theta} d \theta
# $$
#
# **Definition (Laurent series)** In the complex plane, _Laurent series around $z_0$_ is an expansion of the form
# $$
#     f(z) = \sum_{k=-\infty}^\infty f_k (z-z_0)^k
# $$
#
# **Lemma (Fourier series = Laurent series)** On a circle in the complex plane
# $$
#     \gamma_r = \{z_0 + re^{i \theta} : -\pi \leq \theta < \pi \},$$
# Laurent series of $f(z)$ around $z_0$ converges for $z \in C_r$ if the Fourier series of $g(\theta) = f(z_0 + r e^{i \theta})$ converges, and the coefficients are given by
#
# $$
# f_k = {g_k \over r^k} = {1 \over 2 \pi i} \oint_{\gamma_r} {f(\zeta) \over (\zeta - z_0)^{k+1}} d \zeta.
# $$

# %% [markdown]
# Interestingly, analytic properties of $f$ can be used to show decaying properties in $g$:
#
# **Theorem (Decay in Fourier/Laurent coefficients)** Suppose $f(z)$ is analytic in a closed annulus $A_{r,R}(z_0)$ around $z_0$:
# $$A_r(z_0) = \{z : r ≤ | z - z_0 | ≤ R\}$$
# Then for all $k$
# $$|f_k | \leq M\min\left\{{1 \over R^k} , {1 \over r^k}\right\}$$
# where $M = \sup_{z \in  A} |f(z)|$.
#
#
# **Example**
#
# The Fourier coefficients of
# $$g(\theta) = {1 \over 2 - \cos \theta}$$
# satisfies for $k \geq 0$
# $$
#    |g_k| \leq {2 \over 4 - R -R^{-1}} R^{-k}
# $$
# for all $R \leq 2 + \sqrt{3}$:

# %%
g =Fun(θ -> 1/(2-cos(θ)), Laurent(-π .. π))
g₊ = g.coefficients[1:2:end]
scatter(abs.(g₊); yscale=:log10, label="|g_k|")
R = 1.1
scatter!(2/(4-R-inv(R))*R.^(-(0:length(g₊))), label = "R = $R")
R = 3.5
scatter!(2/(4-R-inv(R))*R.^(-(0:length(g₊))), label = "R = $R")
R = 2+sqrt(3)-0.1
scatter!(2/(4-R-inv(R))*R.^(-(0:length(g₊))), label = "R = $R")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 54.5866,375.813 580.315,375.813 580.315,11.811 54.5866,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="11" width="527" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   131.462,370.353 131.462,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   208.957,370.353 208.957,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   286.453,370.353 286.453,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   363.948,370.353 363.948,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   441.443,370.353 441.443,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   518.939,370.353 518.939,17.2711
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,317.067 572.429,317.067
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,223.627 572.429,223.627
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,130.187 572.429,130.187
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4725,36.7467 572.429,36.7467
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.462,375.813 131.462,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   208.957,375.813 208.957,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   286.453,375.813 286.453,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   363.948,375.813 363.948,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   441.443,375.813 441.443,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   518.939,375.813 518.939,370.353
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,375.813 54.5866,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,317.067 62.4725,317.067
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,223.627 62.4725,223.627
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,130.187 62.4725,130.187
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5866,36.7467 62.4725,36.7467
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.462, 389.613)" x="131.462" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 208.957, 389.613)" x="208.957" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 286.453, 389.613)" x="286.453" y="389.613">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 363.948, 389.613)" x="363.948" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 441.443, 389.613)" x="441.443" y="389.613">25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 518.939, 389.613)" x="518.939" y="389.613">30</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 321.567)" x="48.5866" y="321.567">10^-15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 228.127)" x="48.5866" y="228.127">10^-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 134.687)" x="48.5866" y="134.687">10^-5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5866, 41.2467)" x="48.5866" y="41.2467">10^0</text>
# </g>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="69.4657" cy="41.2049" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="69.4657" cy="41.2049" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="84.9647" cy="51.8935" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="84.9647" cy="51.8935" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="100.464" cy="62.582" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="100.464" cy="62.582" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="115.963" cy="73.2706" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="115.963" cy="73.2706" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="131.462" cy="83.9591" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="131.462" cy="83.9591" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#000000; stroke:none; fill-opacity:1" cx="146.961" cy="94.6477" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="146.961" cy="94.6477" r="3"/>
# <circle clip-path="url(#clip02)" style="fill:#0000
