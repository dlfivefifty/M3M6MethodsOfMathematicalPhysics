# %%
using Plots, ComplexPhasePortrait, ApproxFun
gr();

# %% [markdown]
# # M3M6: Methods of Mathematical Physics
#
# $$
# \def\dashint{{\int\!\!\!\!\!\!-\,}}
# \def\infdashint{\dashint_{\!\!\!-\infty}^{\,\infty}}
# \def\D{\,{\rm d}}
# \def\dx{\D x}
# $$
#
# Dr. Sheehan Olver
# <br>
# s.olver@imperial.ac.uk
#
# Office Hours: 3-4pm Mondays, Huxley 6M40
# <br>
# Website: https://github.com/dlfivefifty/M3M6LectureNotes
#
#
#
# # Lecture 7: Integrals over the real line
#
#
# This lecture we cover
#
# 1. Integrals over real lines
#     - Principal value integral
#     - Cauchy's integral formula and Residue theorem on the real line
#     - Jordan's lemma
#     - Application: Calculating Fourier tranforms of weakly decaying functions
# 2. Functions with branch cuts
#     - Logarithmic function

# %% [markdown]
# ## Integrals over the real line
#
# Integrals on the real line are always to viewed as improper integrals:
#
# $$ \int_{-\infty}^\infty f(x) \dx = \int_0^\infty f(x) \dx +\int_{-\infty}^0 f(x)\dx = \lim_{b \rightarrow \infty} \int_0^b f(x) \dx + \lim_{a \rightarrow -\infty} \int_a^0 f(x) \dx.$$
#
# **Definition (Principal value integral on the real line)** The _(Cauchy) principal value integral on the real line_ is defined as
# $$
# \infdashint f(x) \dx := \lim_{M\rightarrow \infty} \int_{-M}^M f(x) \dx
# $$
#
# **Proposition (Integability $\Rightarrow$ Prinipal value integrability)** If
# $ \int_{-\infty}^\infty f(x) \dx < \infty$
# then
# $$ \infdashint f(x) \dx = \int_{-\infty}^\infty f(x) \dx.$$
#
#
# ### Residue theorem on the real line
#
# The real line doesn't have an _inside_ and _outside_, rather an _above_ and _below_, or _left_ and _right_. Thus we get the following two versions of the Residue theorem:
#
# **Definition (Upper/lower half plane)** Denote the upper/lower half plane by
# $$
# {\mathbb H}^+ = \{z : \Re z > 0 \}  \\
# {\mathbb H}^- = \{z : \Re z < 0 \}
# $$
# The closure is denoted
# $$
# \bar{\mathbb H}^+ = {\mathbb H}^+ \cup {\mathbb R} \cup \{\infty\}  \\
# \bar{\mathbb H}^- = {\mathbb H}^- \cup {\mathbb R} \cup \{\infty\}
# $$
#
# **Theorem (Residue theorem on the real line)** Suppose $f : \bar {\mathbb H}^+ \backslash \{z_1,\ldots,z_r \} \rightarrow {\mathbb C}$ is holomorphic in ${\mathbb H}^+ \backslash \{z_1,\ldots,z_r \}$, where $\Re z_k > 0$, and  $\lim_{\epsilon \rightarrow 0} f(x + i \epsilon) = f(x)$ converges uniformly.  If
# $$ \lim_{z \rightarrow \infty} z f(z) = 0
# $$ uniformly for $z \in \bar {\mathbb H}^+$, then
# $$
# \infdashint f(x) \dx = 2 \pi i \sum_{k=1}^r {\underset{z = z_k}{\rm Res}} \, f(z)
# $$
# Similarly, if the equivalent conditions hold in the lower half plane for $f : \bar{\mathbb H}^- \backslash \{z_1,\ldots,z_r \} \rightarrow {\mathbb C}$ then
# $$
# \infdashint f(x) \dx = -2 \pi i \sum_{k=1}^r {\underset{z = z_k}{\rm Res}} \, f(z)
# $$
#
#
# Examples:

# %%
f = x -> x^2/(x^4+1)
phaseplot(f, (-3,3),(-2,2))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0400)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,284.813 572.049,284.813
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,102.812 572.049,102.812
#   "/>
# <polyline clip-path="url(#clip0402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,284.813 37.525,284.813
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,102.812 37.525,102.812
#   "/>
# <polyline clip-path="url(#clip0400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-2</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 289.313)" x="23.2591" y="289.313">-1</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 198.312)" x="23.2591" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 107.312)" x="23.2591" y="107.312">1</text>
# </g>
# <g clip-path="url(#clip0400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 16.311)" x="23.2591" y="16.311">2</text>
# </g>
# <g clip-path="url(#clip0402)">
# <image width="551" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAicAAAFsCAYAAAAXJxnvAAAgAElEQVR4nOy9Xa8sSZYltDLinntv
# Z1Z2VhfVU5rWSDD0AyCGjxdQa6QRvCCheeEPIPEP+E/8BF545hENQgPDy4AEI6HWjFoU3V2Tlbfv
# R8W5PETsE8tXrL1tm7vHuSerc0shdzfbts3c3dz2srXNPb76f/D5MwA84iqny9alQfJOJk3

# %%
sum(Fun(f, -Inf .. Inf))
# Out:
# 2.2214414690864146

# %%
z₁,z₂,z₃,z₄ = exp(im*π/4), exp(3im*π/4), exp(5im*π/4), exp(7im*π/4)
f(z₁),f(z₂)
# Out:
# (2.251799813685248e15 - 0.5im, -2.251799813685248e15 + 0.5im)

# %%
res₁ = z₁^2 / ((z₁ - z₂)*(z₁ - z₃)*(z₁ - z₄) )
res₂ = z₂^2 / ((z₂ - z₁)*(z₂ - z₃)*(z₂ - z₄) )

2π*im*(res₁ + res₂)
# Out:
# 2.221441469079183 + 3.487868498008632e-16im

# %%
res₃ = z₃^2 / ((z₃ - z₁)*(z₃ - z₂)*(z₃ - z₄) )
res₄ = z₄^2 / ((z₄ - z₁)*(z₄ - z₃)*(z₄ - z₂) )

-2π*im*(res₃ + res₄)
# Out:
# 2.221441469079183 + 5.231802747012948e-16im

# %% [markdown]
# An immediate consequence of this result is Cauchy's integral formula on the real line:
#
# **Theorem (Cauchy's integral formula on the real line)** Suppose $f : \bar {\mathbb H}^+  \rightarrow {\mathbb C}$ is holomorphic in ${\mathbb H}^+ $, and  $\lim_{\epsilon \rightarrow 0} f(x + i \epsilon) = f(x)$ converges uniformly.  If
# $$
# \lim_{z \rightarrow \infty} f(z) = 0
# $$
# uniformly for $z \in \bar {\mathbb H}^+$, then
# $$
# f(z) = {1 \over 2 \pi i} \infdashint {f(x) \over x - z} dx
# $$
# for all  $z \in {\mathbb H}^+$.
#
#
# _Examples_ Here is a simple example of $f(x) = {x^2 \over (x+ i)^3}$, which is analytic in the upper half plane:

# %%
f = x -> x^2/(x+im)^3
z = 2.0+2.0im
sum(Fun(x-> f(x)/(x - z), -Inf .. Inf))/(2π*im) - f(z)
# Out:
# 3.617037225289721e-13 - 2.8191338152794287e-13im

# %% [markdown]
# Evaluating in lower half plane doesn't work:

# %%
f = x -> x^2/(x+im)^3
z = 2.0-2.0im
sum(Fun(x-> f(x)/(x - z), -Inf .. Inf))/(2π*im) , f(z)
# Out:
# (6.613124107814175e-14 - 4.566746430997029e-13im, 0.7040000000000001 - 0.128im)

# %% [markdown]
# But does for a function analytic in the lower half plane (with a minus sign):

# %%
f = x -> x^2/(x-im)^3
z = 2.0-2.0im
-sum(Fun(x-> f(x)/(x - z), -Inf .. Inf))/(2π*im) , f(z)
# Out:
# (0.032771961766406316 + 0.16750113791562102im, 0.03277196176604461 + 0.1675011379153391im)

# %% [markdown]
# It also works for functions with exponential decay in the upper-half plane:

# %%
f = x -> exp(im*x)/(x+im)
z = 2 + 2im
sum(Fun(x-> f(x)/(x - z), -500 .. 500))/(2π*im) - f(z)
# Out:
# 4.501316791527543e-9 + 5.93330299732131e-7im

# %% [markdown]
# This is difficult as a real integral as the integrand is very oscillatory:

# %%
xx = linspace(-200,200,1000)
plot(xx,real.(f.(xx)))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0600)" points="
# 39.1436,375.813 580.315,375.813 580.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,370.353 39.1436,17.2711
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   174.436,370.353 174.436,17.2711
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.729,370.353 309.729,17.2711
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   445.022,370.353 445.022,17.2711
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,333.91 572.197,333.91
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,287.211 572.197,287.211
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,240.511 572.197,240.511
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,193.812 572.197,193.812
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,147.113 572.197,147.113
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,100.414 572.197,100.414
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,53.7148 572.197,53.7148
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 39.1436,11.811
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 39.1436,370.353
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   174.436,375.813 174.436,370.353
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.729,375.813 309.729,370.353
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   445.022,375.813 445.022,370.353
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,333.91 47.2612,333.91
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,287.211 47.2612,287.211
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,240.511 47.2612,240.511
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,193.812 47.2612,193.812
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,147.113 47.2612,147.113
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,100.414 47.2612,100.414
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,53.7148 47.2612,53.7148
#   "/>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.1436, 389.613)" x="39.1436" y="389.613">-200</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 174.436, 389.613)" x="174.436" y="389.613">-100</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.729, 389.613)" x="309.729" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 445.022, 389.613)" x="445.022" y="389.613">100</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">200</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 338.41)" x="33.1436" y="338.41">-0.6</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 291.711)" x="33.1436" y="291.711">-0.4</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 245.011)" x="33.1436" y="245.011">-0.2</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 198.312)" x="33.1436" y="198.312">0.0</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 151.613)" x="33.1436" y="151.613">0.2</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 104.914)" x="33.1436" y="104.914">0.4</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 58.2148)" x="33.1436" y="58.2148">0.6</text>
# </g>
# <polyline clip-path="url(#clip0602)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,194.376 39.6853,193.933
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.6853,193

# %%
phaseplot(f, (-3,3), (-3,3))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran

# %% [markdown]
# An equivalent result holds in the negative real axis, but be careful:

# %%
z = -2-im
sum(Fun(x-> f(x)/(x - z), -500 .. 500))/(2π*im)
# Out:
# -4.529525112332076e-9 + 5.865568293168583e-7im

# %%
z = -2-im
f = x -> exp(im*x)/(x-im)
sum(Fun(x-> f(x)/(x - z), -500 .. 500))/(2π*im), f(z)
# Out:
# (0.09196985577264769 - 0.09196926921581833im, 0.9007327639404081 + 0.3351305720620013im)

# %%
z = -2-im
f = x -> exp(-im*x)/(x-im)
-sum(Fun(x-> f(x)/(x - z), -500 .. 500))/(2π*im), f(z)
# Out:
# (-0.045354995402086956 - 0.12190151480555919im, -0.04535499089125899 - 0.12190092372837213im)

# %% [markdown]
# ### Jordan's lemma
#
# The case of calculating
# $$
#     \int_{-\infty}^\infty e^{i \omega x} g(x) dx
# $$
# is important because it is the Fourier transform of $g(x)$. Provided $g$ is defined in the upper half plane and $\omega > 0$, $f(z) = e^{i \omega z} g(z)$  has exponential decay:

# %%
phaseplot(z -> exp(2im*z) / (z - im), (-4,4), (-4,4))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   167.023,370.353 167.023,17.2711
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   442.551,370.353 442.551,17.2711
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,284.813 572.049,284.813
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,102.812 572.049,102.812
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   167.023,375.813 167.023,370.353
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   442.551,375.813 442.551,370.353
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,284.813 37.525,284.813
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,102.812 37.525,102.812
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-4</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 167.023, 389.613)" x="167.023" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 442.551, 389.613)" x="442.551" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-4</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 289.313)" x="23.2591" y="289.313">-2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 198.312)" x="23.2591" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 107.312)" x="23.2591" y="107.312">2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 16.311)" x="23.2591" y="16.311">4</text>
# </g>
# <g clip-path="url(#clip1002)">
# <image width="551" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAicAAAFsCAYAAAAXJxnvAAAgAElEQVR4nOy90ZbbOKwsitiT2eez
# 72efM9l234c2Y6hUVQAp2enMBGtltUWCkEiRQLFAO98+/r/4iIiI/4mI//P49x2ux+dI139znX8u
# Ef/vofojIv7v49//g8+5Lor6/0d0/yFt/m9qN54h19/j70fncqdGx/4n1WF9bhOg49rgwP4P2HuU
# /e9f2wGrBmN0jOm7AWCDOsrwJfx4Xv/Px/aVd0ZglAUpY3poF6dgvo7U5m/34JuOYefZDAqip64j
# +ECC3pgG2Fl2nfXcesw2lS02sOQF3C7bXuQRYGsKp0w1Sm7N4pv6kXRH2f/GN+hYHpAgZeo6Gi+A
# zdpC7+NvP0h5YDt6P5KuWtfNdXv5x6+bzvpya7bynNX0/jvuqVM4O0bHnNPCwUU7bsYqBzruGRHX
# Wz8usrDCBiZCTytsE6T+8QwsHLAeVSPgQkMU9XnE4/H5/9H1igMRYiC3A3IJJpeIuNKarU4ht8W6
# Tv19sZ3vmKpznXVtGoOURXVKCevsrI03SjWlnPRHsjsAqwNVz7C2HBmQ3+F+L5ETx//d91sd/267
# pt4RF/GF3UtwLzHpg2f1b6GniBusM9s8ZCV6Ha3vjVY1a+7BOudtV5O9sRheCVBW3m8tZwKUBX32
# 8LP+cQa5TQyiGgHWm6P+9HwwshpkTgxOs37yiPwrgEhX3glYfh+wcv/W0zvqR2dcFi9XC4OVq86f
# 4YONjdnX7vTXd9ZSZkYwy5EQ3xvx9Sh/KTf4FYtyqXU4LnrWVfWr71mD2k6nmFxNu9k2ZtBnQYTS
# 79oZL6Ghq3rTdQ1H9jZ999Nd5TMDPWvrhQGTrdn/FBiphL2LF74PHPszQcfJi+PIyjgKVvi9lTfp
# DoYKYFdRruxMApNb6AFx5SvARPj40cOZTeMQFwFH3XpOYAzOQqeSjec9OhDqYKrnCFOyAlDq+lVc
# uDodunaCP/RZnOrEArl8rN9GTeKvBUZW5MXBDgfonYzLf0Z+MZg8YqsjbwArx1fBK5kRJZMIcJbJ
# XgUfSkS7I6mYI2xIDQGqgNGZNfeHLbzzwQTVOlCo61eB52dbxXEewZ6zbU7Qn2FEIl6WJD4ju5ul
# g31n9I65zTcHrj/yReWFJyzOBKCNts53ZjkKON57DG6WGVnwtWfor5wjWT3LEh7eHQEmR8+u9OiJ
# pw631+mFATLjFg5IVO+rYlFmshNP6XQKxRFgJ6V41IM75mvGCxxMCh8lR2fSQOsM+SrpfObxwIat
# P2DkNxbyfr/BTvGVoONI7pR

# %% [markdown]
# We can use this to get sharper results than ML inequality:
#
# **Lemma (Jordan)** Assume $\omega > 0$. If $g(z)$ is continuous in on the half circle $C_R = \{ R e^{i \theta} : 0 \leq \theta \leq \pi \}$  then
# $$\left| \int_{C_R} g(z) e^{i \omega z} dz \right| \leq {\pi \over \omega} M$$
# where $M = \sup_{z \in C_R} |g(z)|$.
#
# **Sketch of proof** We have
# $$\left| \int_{C_R} g(z) e^{i \omega z} dz \right|  \leq   R \int_0^\pi \left|g(R e^{i \theta}) e^{i \omega R e^{i \theta}}e^{i \theta}\right| d\theta
# \leq MR \int_0^\pi e^{- \omega R\sin \theta } d\theta
# = 2MR \int_0^{\pi\over 2} e^{- \omega R\sin \theta } d\theta
# $$
# But we have $\sin \theta \geq {2 \theta \over \pi}$:

# %%
θ = linspace(0,π/2,100)
plot(θ, sin.(θ); label="sin t")
plot!(θ, 2θ/π; label = "2t / pi")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,370.353 32.2221,17.2711
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   206.685,370.353 206.685,17.2711
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   381.149,370.353 381.149,17.2711
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   555.612,370.353 555.612,17.2711
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,375.813 572.094,375.813
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,303.013 572.094,303.013
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,230.212 572.094,230.212
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,157.412 572.094,157.412
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,84.6115 572.094,84.6115
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,11.811 572.094,11.811
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,370.353
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   206.685,375.813 206.685,370.353
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   381.149,375.813 381.149,370.353
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   555.612,375.813 555.612,370.353
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 40.4435,375.813
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,303.013 40.4435,303.013
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,230.212 40.4435,230.212
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,157.412 40.4435,157.412
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,84.6115 40.4435,84.6115
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,11.811 40.4435,11.811
#   "/>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 389.613)" x="32.2221" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 206.685, 389.613)" x="206.685" y="389.613">0.5</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 381.149, 389.613)" x="381.149" y="389.613">1.0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 555.612, 389.613)" x="555.612" y="389.613">1.5</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 380.313)" x="26.2221" y="380.313">0.0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 307.513)" x="26.2221" y="307.513">0.2</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 234.712)" x="26.2221" y="234.712">0.4</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 161.912)" x="26.2221" y="161.912">0.6</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 89.1115)" x="26.2221" y="89.1115">0.8</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 16.311)" x="26.2221" y="16.311">1.0</text>
# </g>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 37.7584,370.038
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   37.7584,370.038 43.2947,364.264
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   43.2947,364.264 48.831,358.494
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.831,358.494 54.3673,352.727
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.3673,352.727 59.9036,346.966
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   59.9036,346.966 65.4399,341.213
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   65.4399,341.213 70.9761,335.468
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   70.9761,335.468 76.5124,329.733
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.5124,329.733 82.0487,324.011
#   "/>
# <poly

# %% [markdown]
# Hence
# $$\left| \int_{C_R} g(z) e^{i \omega z} dz \right|  \leq  2MR \int_0^{\pi\over 2} e^{- {2\omega R\theta \over \pi} } d\theta = {\pi \over \omega} (1 - e^{-\omega R}) M \leq {\pi M \over \omega}.
# $$

# %% [markdown]
# ## Application: Calculating Fourier integrals of weakly decaying functions
#
# Why is this useful? We can use it to apply Residue theorem to We already know $O(z^{-2})$ decay gives us the integral via Residue theorem. And if we only have $z^{-1}$ decay our integral does not converge absolutely:

# %%
f = x -> exp(im*x)*x/(x^2+1)

sum(abs.(Fun(f, 0 .. 2000)))
# Out:
# 7.600902584542068

# %% [markdown]
# However, it does converge conditionally:

# %%
f = x -> exp(im*x)*x/(x^2+1)

sum(Fun(f, -30000 .. 30000))
# Out:
# 4.0657581468206416e-20 + 1.155767113543384im

# %% [markdown]
# Thus we can construct a Residue theorem for calculating
# $$
# \infdashint g(x) e^{i \omega x} \dx
# $$
# provided that $g(z) \rightarrow 0$ and is analytic in the upper-half plane.

# %%
2π*im*exp(-1)*im/(im+im)  # 2π*im* residue of g(z)exp(im*z) at z = im
# Out:
# 0.0 + 1.1557273497909217im

# %% [markdown]
# ## Functions with branch cuts
#
# We now discuss functions with branch cuts
#
# 1. $\log z$ with a cut on $(-\infty,0]$
# 2. $z^\alpha$ with a cut on $(-\infty,0]$
# 3. $\sqrt{z-1}\sqrt{z+1}$ with a cut on $[-1,1]$
# 4. $\rm{sign}(|z|-1)$ with a cut on the unit circle.
#
# This is a step towards a Cauchy integral theorem on cuts, for recovering a holomorphic function from its behaviour on a cut.
#
# We begin with $\log z$.
#
# **Definition (Complex Logarithm)**
# $$\log z = \int_1^z {1 \over \zeta} d\zeta$$
# where the integral is understood to be on a straight line segment, that is
# $$\log z = \int_{\gamma_z} {1 \over \zeta} d\zeta$$
# where
# $\gamma_z(t) = 1 + (z-1)t$ for $0 \leq t \leq 1$.

# %%
z = -2 + 1.0im
phaseplot(ζ -> 1/ζ, (-3,3), (-3,3))
plot!(Segment(1,z); color=:black, label="contour")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2600)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran

# %% [markdown]
# This is well-defined apart from $z \in (-\infty,0]$, where there is a pole on the contour:

# %%
log(-2+0.000001im)
# Out:
# 0.6931471805600703 + 3.141592153589793im

# %%
log(-2-0.000001im)
# Out:
# 0.6931471805600703 - 3.141592153589793im

# %%
phaseplot(z -> log(z), (-3,3), (-3,3))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran

# %% [markdown]
# It does exist in the limit, though:

# %%
log(-1+0.0im), log(-1-0.0im)
# Out:
# (0.0 + 3.141592653589793im, 0.0 - 3.141592653589793im)

# %% [markdown]
# By deformation, the value of the integrals is independent of the path:

# %%
log( exp(im*0.9π))
# Out:
# -1.3877787807814457e-17 + 2.827433388230814im

# %%
sum(Fun(z -> 1/z, Arc(0.,1.,(0.,0.9π))))
# Out:
# 4.3786740587532857e-16 + 2.8274333882308116im

# %%
phaseplot(ζ -> 1/ζ, (-3,3), (-3,3))
plot!(Segment(1.0, exp(0.9π*im)); ratio=1.0, color=:black, label="original contour")
plot!(Arc(0.,1.,(0.,0.9π)); ratio=1.0, color=:grey, label="deformed contour")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2800)" points="
# 122.786,375.813 486.788,375.813 486.788,11.811 122.786,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="122" y="11" width="365" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   122.786,370.353 122.786,17.2711
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   183.453,370.353 183.453,17.2711
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   244.12,370.353 244.12,17.2711
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   365.454,370.353 365.454,17.2711
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   426.121,370.353 426.121,17.2711
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   486.788,370.353 486.788,17.2711
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.246,375.813 481.328,375.813
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.246,315.146 481.328,315.146
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.246,254.479 481.328,254.479
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.246,193.812 481.328,193.812
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.246,133.145 481.328,133.145
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.246,72.4781 481.328,72.4781
#   "/>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.246,11.811 481.328,11.811
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,375.813 486.788,375.813
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,375.813 122.786,11.811
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,375.813 122.786,370.353
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.453,375.813 183.453,370.353
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   244.12,375.813 244.12,370.353
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   365.454,375.813 365.454,370.353
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   426.121,375.813 426.121,370.353
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   486.788,375.813 486.788,370.353
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,375.813 128.246,375.813
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,315.146 128.246,315.146
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,254.479 128.246,254.479
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,193.812 128.246,193.812
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,133.145 128.246,133.145
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,72.4781 128.246,72.4781
#   "/>
# <polyline clip-path="url(#clip2800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.786,11.811 128.246,11.811
#   "/>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 122.786, 389.613)" x="122.786" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 183.453, 389.613)" x="183.453" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 244.12, 389.613)" x="244.12" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 365.454, 389.613)" x="365.454" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 426.121, 389.613)" x="426.121" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 486.788, 389.613)" x="486.788" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 116.786, 380.313)" x="116.786" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 116.786, 319.646)" x="116.786" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 116.786, 258.979)" x="116.786" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip2800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-an

# %% [markdown]
# This works all the way to the negative real axis:

# %%
log(-1+0im), log(-1.0 -0im)
# Out:
# (0.0 + 3.141592653589793im, 0.0 - 3.141592653589793im)

# %%
sum(Fun(ζ -> 1/ζ, Arc(0.,1.,(0.,π)))),
sum(Fun(ζ -> 1/ζ, Arc(0.,1.,(0.,-π))))
# Out:
# (9.692284352069069e-17 + 3.1415926535897905im, 9.692284352069069e-17 - 3.1415926535897905im)

# %% [markdown]
# Combining the two contours we have:

# %%
log(-1.0+0im) - log(-1.0-0im),

sum(Fun(ζ -> 1/ζ, Circle()))
# Out:
# (0.0 + 6.283185307179586im, -7.320437517164298e-16 + 6.283185307179586im)

# %% [markdown]
# We can establish some properties. First we show that $\log z = - \log {1 \over z}$ by considering the change of variables $\zeta = {1 \over s}$.  Because $\gamma_z(t)^{-1}$ stays uniformly in the lower-half plane, we can deform it to a straight contour, which gives us the result:
# $$
# \log z = \int_{\gamma_z} {\D\zeta \over \zeta} = -\int_{{1 \over \zeta} \circ \gamma_z} {\D s \over s} = - \int_{\gamma_{z^{-1}}} {\D s \over s} = -\log z^{-1}
# $$
#
# Here's a plot of the relevant contours:

# %%
phaseplot(z -> log(z), (-3,3), (-3,3))
z = -2 + 2im

γ = (z,t) -> 1 + t*(z-1)
tt = linspace(0.,1.,100)
plot!((γ.(z,tt)); color=:black, label="contour")
plot!((1./γ.(z,tt)); color=:black, linestyle=:dot, label="change of variables contour")
plot!((γ.(1/z,tt)); color=:black, linestyle=:dashdot, label="deformed contour")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 45.0072,360.065 580.315,360.065 580.315,11.811 45.0072,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="536" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.0072,354.842 45.0072,17.0348
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   134.225,354.842 134.225,17.0348
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   223.443,354.842 223.443,17.0348
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   312.661,354.842 312.661,17.0348
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   401.879,354.842 401.879,17.0348
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.097,354.842 491.097,17.0348
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,354.842 580.315,17.0348
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,360.065 572.285,360.065
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,302.023 572.285,302.023
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,243.981 572.285,243.981
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,185.938 572.285,185.938
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,127.896 572.285,127.896
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,69.8534 572.285,69.8534
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,11.811 572.285,11.811
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 45.0072,11.811
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 45.0072,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   134.225,360.065 134.225,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   223.443,360.065 223.443,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   312.661,360.065 312.661,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   401.879,360.065 401.879,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.097,360.065 491.097,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,354.842
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 53.0368,360.065
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,302.023 53.0368,302.023
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,243.981 53.0368,243.981
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,185.938 53.0368,185.938
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,127.896 53.0368,127.896
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,69.8534 53.0368,69.8534
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,11.811 53.0368,11.811
#   "/>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.0072, 373.865)" x="45.0072" y="373.865">-3</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 134.225, 373.865)" x="134.225" y="373.865">-2</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 223.443, 373.865)" x="223.443" y="373.865">-1</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 312.661, 373.865)" x="312.661" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 401.879, 373.865)" x="401.879" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.097, 373.865)" x="491.097" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 364.565)" x="39.0072" y="364.565">-3</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 306.523)" x="39.0072" y="306.523">-2</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 248.481)" x="39.0072" y="248.481">-1</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; te

# %%
phaseplot(z -> -log(1/z), (-3,3), (-3,3))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,370.353 29.2591,17.2711
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.102,370.353 121.102,17.2711
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.944,370.353 212.944,17.2711
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.787,370.353 304.787,17.2711
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.63,370.353 396.63,17.2711
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.472,370.353 488.472,17.2711
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,375.813 572.049,375.813
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,315.146 572.049,315.146
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,254.479 572.049,254.479
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,193.812 572.049,193.812
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,133.145 572.049,133.145
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,72.4781 572.049,72.4781
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,11.811 572.049,11.811
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,370.353
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.102,375.813 121.102,370.353
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.944,375.813 212.944,370.353
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   304.787,375.813 304.787,370.353
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.63,375.813 396.63,370.353
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.472,375.813 488.472,370.353
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 37.525,375.813
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,315.146 37.525,315.146
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,254.479 37.525,254.479
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,193.812 37.525,193.812
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,133.145 37.525,133.145
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,72.4781 37.525,72.4781
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,11.811 37.525,11.811
#   "/>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 29.2591, 389.613)" x="29.2591" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.102, 389.613)" x="121.102" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.944, 389.613)" x="212.944" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 304.787, 389.613)" x="304.787" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.63, 389.613)" x="396.63" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 488.472, 389.613)" x="488.472" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 380.313)" x="23.2591" y="380.313">-3</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 319.646)" x="23.2591" y="319.646">-2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 258.979)" x="23.2591" y="258.979">-1</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" tran
